# %% [markdown]
# # Extract Soil Data
# Parses all the soil survey areas in Arizona and extract the soil data in tabular format

# %%
import sys
base_path = "src/"
if base_path not in sys.path:
    sys.path.append(base_path)

# %%
import pathlib

import pandas as pd

from dataloaders import (
    load_area_legend_db, 
    load_chorizon_db, 
    load_component_db, 
    load_mapunit_db
)

# %% [markdown]
# We need to add the areaname and legend to each table

# %%
base_dir = "./datasets/arizona/"
area_symbols = [folder.stem for folder in pathlib.Path(base_dir).iterdir() if folder.is_dir()]
chorizon__table_filename_suffix = "chorizon.txt"
area_legend_table_filename_suffix = "legend.txt"
component_table_filename_suffix = "comp.txt"
mapunit_table_filename_suffix = "mapunit.txt"

# %% [markdown]
# We need to left join the mapunit table to the component table.
# We then need to left join this table to the chorizon table.
# Finally we need to filter the table to the columns we need.
# Then we save

# %%
target_column_names =[
    "mukey",
    "muname",
    "musym",
    "farmlndcl",
    "cokey",
    "compname",
    "comppct_r",
    "desgnmaster",
    "chkey",
    "sandtotal_l",
    "sandtotal_r",
    "sandtotal_h",
    "silttotal_l",
    "silttotal_r",
    "silttotal_h",
    "claytotal_l",
    "claytotal_r",
    "claytotal_h",
    "ph1to1h2o_l",
    "ph1to1h2o_r",
    "ph1to1h2o_h",
    "ksat_l",
    "ksat_r",
    "ksat_h"
]

# %%
final_columnname_remappings = {
    "mukey": "mapunit_key",
    "muname": "mapunit_name",
    "musymbol": "mapunit_symbol",
    "farmlndcl": "farmland_status",
    "cokey": "component_key",
    "compname": "component_name",
    "comppct_r": "component_percent_of_mapunit",
    "chkey": "chorizon_key",
    "desgnmaster": "master_soil_horizon_id",
    "sandtotal_l": "frac_weight_sand_layer_low",
    "sandtotal_r": "frac_weight_sand_layer_reg",
    "sandtotal_h": "frac_weight_sand_layer_high",
    "silttotal_l": "frac_weight_silt_layer_low",
    "silttotal_r": "frac_weight_silt_layer_reg",
    "silttotal_h": "frac_weight_silt_layer_high",
    "claytotal_l": "frac_weight_clay_layer_low",
    "claytotal_r": "frac_weight_clay_layer_reg",
    "claytotal_h": "frac_weight_clay_layer_high",
    "ph1to1h2o_l": "ph_layer_low",
    "ph1to1h2o_r": "ph_layer_reg",
    "ph1to1h2o_h": "ph_layer_high",
    "ksat_l": "amount_water_movement_low",
    "ksat_r": "amount_water_movement_reg",
    "ksat_h": "amount_water_movement_high"
}

# %% [markdown]
# ### Test Case

# %%
area_dir = base_dir + "AZ701/tabular/"

# %%
component_df = load_component_db(area_dir + component_table_filename_suffix)
chorizon_df = load_chorizon_db(area_dir + chorizon__table_filename_suffix)
legend_df = load_area_legend_db(area_dir + area_legend_table_filename_suffix)
mapunit_df = load_mapunit_db(area_dir + mapunit_table_filename_suffix)

# %%
component_df
# Out:
#      comppct_l  comppct_r  comppct_h  ... vasoimgtgrp   mukey     cokey
# 0          NaN         40        NaN  ...         NaN  615954  25724121
# 1          NaN         41        NaN  ...         NaN  615954  25724122
# 2          NaN         19        NaN  ...         NaN  615954  25724123
# 3          NaN         20        NaN  ...         NaN  615955  25724124
# 4          NaN         80        NaN  ...         NaN  615955  25724125
# ..         ...        ...        ...  ...         ...     ...       ...
# 447        NaN         40        NaN  ...         NaN  616118  25724401
# 448        NaN          5        NaN  ...         NaN  616118  25724402
# 449        NaN         10        NaN  ...         NaN  616128  25724403
# 450        NaN         60        NaN  ...         NaN  616128  25724404
# 451        NaN         30        NaN  ...         NaN  616128  25724405
#
# [452 rows x 109 columns]

# %%
mapunit_df
# Out:
#      musym                                             muname  ...   lkey   mukey
# 0        1            Albers clay loam, 0 to 1 percent slopes  ...  10290  615792
# 1        2         Argic Petrocalcids, 8 to 15 percent slopes  ...  10290  615793
# 2        3   Argic Petrocalcids, warm, 2 to 30 percent slopes  ...  10290  615794
# 3        4  Aridic Haplustalfs-Lithic Haplustalfs complex,...  ...  10290  615795
# 4        5          Aridic Haplustepts, 0 to 8 percent slopes  ...  10290  615796
# ..     ...                                                ...  ...    ...     ...
# 172    175  Yumtheska-Toqui-Rock outcrop complex, 2 to 8 p...  ...  10290  616067
# 173    176  Yumtheska-Toqui-Rock outcrop complex, 15 to 40...  ...  10290  616068
# 174    177               Zibate family, 2 to 8 percent slopes  ...  10290  616069
# 175    159  Valleycity-Berzatic-Seeg families complex, 8 t...  ...  10290  616118
# 176     81  Meriwhitica-Tassi complex, 0 to 33 percent slopes  ...  10290  616128
#
# [177 rows x 24 columns]

# %%
component_merged_df = pd.merge(component_df, mapunit_df, on='mukey', how='left')
assert len(component_merged_df) == len(component_df)

# %%
component_merged_df.head()
# Out:
#    comppct_l  comppct_r  comppct_h  ... vtsepticsyscl mucertstat   lkey
# 0        NaN         40        NaN  ...           NaN        NaN  10290
# 1        NaN         41        NaN  ...           NaN        NaN  10290
# 2        NaN         19        NaN  ...           NaN        NaN  10290
# 3        NaN         20        NaN  ...           NaN        NaN  10290
# 4        NaN         80        NaN  ...           NaN        NaN  10290
#
# [5 rows x 132 columns]

# %%
chorizon_merged_df = pd.merge(chorizon_df, component_merged_df, on='cokey', how='left')
assert len(chorizon_df) == len(chorizon_merged_df)

# %%
chorizon_merged_df.head()
# Out:
#   hzname  desgndisc desgnmaster  ...  vtsepticsyscl  mucertstat   lkey
# 0    3Ab        NaN           A  ...            NaN         NaN  10290
# 1     A2        NaN           A  ...            NaN         NaN  10290
# 2    Bw1        NaN           B  ...            NaN         NaN  10290
# 3  2Btk1        NaN           B  ...            NaN         NaN  10290
# 4  2Btk2        NaN           B  ...            NaN         NaN  10290
#
# [5 rows x 302 columns]

# %%
chorizon_merged_df["areaname"] = legend_df.areaname.unique()[0]
chorizon_merged_df["areasymbol"] = legend_df.areasymbol.unique()[0]
output_df = chorizon_merged_df[target_column_names].rename(columns=final_columnname_remappings)
output_df.shape

# %% [markdown]
# # Process All Arizona

# %%
def process_all(base_dir: str, area_symbols: list[str], target_column_names: list[str]) -> pd.DataFrame:
    final_df = None
    for symbol in area_symbols:
        print(f"Processing area with symbol {symbol}", end="...")
        area_dir = pathlib.Path(base_dir).joinpath(symbol).joinpath("tabular")
        component_df = load_component_db(area_dir.joinpath(component_table_filename_suffix))
        chorizon_df = load_chorizon_db(area_dir.joinpath(chorizon__table_filename_suffix))
        legend_df = load_area_legend_db(area_dir.joinpath(area_legend_table_filename_suffix))
        mapunit_df = load_mapunit_db(area_dir.joinpath(mapunit_table_filename_suffix))
        if len(chorizon_df) < 1:
            print(f"Skipping {symbol} as no horizon data", end="\n")
            continue

        print(f"Found {len(chorizon_df)} rows in horizon dataset", end="\n")
        component_merged_df = pd.merge(component_df, mapunit_df, on='mukey', how='left')
        chorizon_merged_df = pd.merge(chorizon_df, component_merged_df, on='cokey', how='left')
        output_df = chorizon_merged_df[target_column_names].copy()
        output_df["areaname"] = legend_df.areaname.unique()[0]
        output_df["areasymbol"] = legend_df.areasymbol.unique()[0]
        if final_df is None:
            final_df = output_df
        else:
            final_df = pd.concat([final_df, output_df])

    return final_df

# %%
output_df = process_all(base_dir, area_symbols, target_column_names)
output_df = output_df.rename(columns=final_columnname_remappings)
output_df.to_csv("./mapped_soil_data.csv", index=False)
# Out:
# Processing area with symbol AZ633...Found 259 rows in horizon dataset
# Processing area with symbol AZ658...Found 164 rows in horizon dataset
# Processing area with symbol AZ693...Found 176 rows in horizon dataset
# Processing area with symbol AZ667...Found 351 rows in horizon dataset
# Processing area with symbol AZ669...Found 461 rows in horizon dataset
# Processing area with symbol AZ656...Found 163 rows in horizon dataset
# Processing area with symbol AZ651...Found 552 rows in horizon dataset
# Processing area with symbol AZ635...Found 422 rows in horizon dataset
# Processing area with symbol AZ668...Found 260 rows in horizon dataset
# Processing area with symbol AZ657...Found 849 rows in horizon dataset
# Processing area with symbol AZ695...Found 843 rows in horizon dataset
# Processing area with symbol AZ661...Found 672 rows in horizon dataset
# Processing area with symbol AZ659...Found 167 rows in horizon dataset
# Processing area with symbol AZ666...Found 628 rows in horizon dataset
# Processing area with symbol AZ714...Found 158 rows in horizon dataset
# Processing area with symbol NM717...Found 2089 rows in horizon dataset
# Processing area with symbol AZ713...Found 574 rows in horizon dataset
# Processing area with symbol AZ723...Skipping AZ723 as no horizon data
# Processing area with symbol UT689...Found 257 rows in horizon dataset
# Processing area with symbol AZ712...Found 141 rows in horizon dataset
# Processing area with symbol AZ715...Found 1164 rows in horizon dataset
# Processing area with symbol AZ701...Found 842 rows in horizon dataset
# Processing area with symbol AZ707...Found 642 rows in horizon dataset
# Processing area with symbol AZ643...Found 307 rows in horizon dataset
# Processing area with symbol AZ675...Found 669 rows in horizon dataset
# Processing area with symbol AZ687...Found 304 rows in horizon dataset
# Processing area with symbol AZ673...Found 369 rows in horizon dataset
# Processing area with symbol AZ645...Found 595 rows in horizon dataset
# Processing area with symbol AZ629...Found 221 rows in horizon dataset
# Processing area with symbol AZ627...Found 725 rows in horizon dataset
# Processing area with symbol AZ663...Found 190 rows in horizon dataset
# Processing area with symbol AZ697...Found 1088 rows in horizon dataset
# Processing area with symbol AZ664...Found 205 rows in horizon dataset
# Processing area with symbol AZ699...Found 361 rows in horizon dataset
# Processing area with symbol AZ655...Found 97 rows in horizon dataset
# Processing area with symbol AZ639...Found 302 rows in horizon dataset
# Processing area with symbol AZ637...Found 703 rows in horizon dataset
# Processing area with symbol AZ653...Found 343 rows in horizon dataset
# Processing area with symbol AZ665...Found 118 rows in horizon dataset
# Skipping AZ691 as no horizon data...
# Processing area with symbol AZ662...Found 205 rows in horizon dataset
# Processing area with symbol AZ631...Found 954 rows in horizon dataset
# Processing area with symbol AZ711...Found 642 rows in horizon dataset
# Processing area with symbol AZ703...Found 343 rows in horizon dataset
# Processing area with symbol AZ625...Found 311 rows in horizon dataset
# Processing area with symbol NV608...Found 1101 rows in horizon dataset
# Processing area with symbol AZ647...Skipping AZ647 as no horizon data
# Processing area with symbol AZ671...Found 989 rows in horizon dataset
# Processing area with symbol AZ649...Found 101 rows in horizon dataset
# Processing area with symbol AZ623...Found 585 rows in horizon dataset
# Processing area with symbol AZ683...Found 379 rows in horizon dataset
# Processing area with symbol AZ648...Skipping AZ648 as no horizon data
# Processing area with symbol AZ646...Found 57 rows in horizon dataset
# Processing area with symbol AZ641...Found 343 rows in horizon dataset

# %%
output_df.shape
# Out:
# (24441, 26)
